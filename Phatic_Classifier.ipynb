# %% [markdown]
# ### Approach
# The task is modelled as a binary topic classification task for sentences/text, where two classes are:
# 0: Ubuntu content sentence
# 1: Phatic sentence
#
# #### Dataset modeling for Classification
# To create the dataset for class 0 (Ubuntu content sentence), all the messages are parsed into sentences, and the sentences
# of token length 7 or more are collected. Taking the large sentences only increase the probability of having content
# words in the sentence, while the phatic sentences generally tend to be of smaller length.
#
# For class 1 (Phatic sentence), any non Ubuntu(or related) topic conversation / dialogue dataset can be used. The assumption is
# that any other dialogue data would also contain phatic sentences in addition to the topic related sentences.
#
# However, learning a classifier to discriminate between these two classes would essentially be basing its decision on two aspects, 1. Topic of the sentence i.e. Ubuntu or other, 2. The classifier would have only seen the phatic sentences
# in the class 1 dataset i.e. non Ubuntu topic conversations.
#
# A publicly available dataset of travel related customer support (RSiCS - https://s3-us-west-2.amazonaws.com/nextit-public/rsics.html),is used to model the class 1 (Phatic sentence) data. For this exercise, "tagged_selections_by_sentence.csv" from RSiCS dataset is used, which contains manual annotations for segmenting the dialogue into two key pieces - conveys the intent or not, in addition to further annotations like Greetings, Rant etc.
#
# #### Evaluation
# The classifier is evaluated on:
# 1. Validation set: A portion of the dataset created above.
# 2. Test set: Phatic examples as provided in the instructions mixed with some non-phatic sentences. A mock small test set.
#
# Accuracy scores are being used as metric for evaluation.

# %%
import numpy as np
import pandas as pd
import os
import pickle


from collections import defaultdict
from nltk import sent_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation as lda
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
def get_sentences(x):
    return sent_tokenize(x)

def contains_min_tokens(x, num_tokens):
    return len(x.split()) > num_tokens

def contains_max_tokens(x, num_tokens):
    return len(x.split()) < num_tokens

def expand(series):
    return pd.Series([x for _list in series for x in _list])

# %%
def get_data(data, col_name, init_sample_size, num_tokens=0, is_min=None):
    data = data.dropna(subset=[col_name])
    data_sample = data[col_name]
    data_sample = data_sample.sample(n=init_sample_size).to_frame()

    z = data_sample[col_name].apply(lambda x: get_sentences(x))
    z = z.to_frame()
    print(z.shape)

    texts = pd.DataFrame({col_name: expand(z[col_name])})
    print(texts.shape)
    if is_min is None:
        return texts

    if is_min:
        func = contains_min_tokens
    else:
        func = contains_max_tokens

    texts = texts[texts[col_name].apply(lambda x: func(x, num_tokens))]
    print(texts.shape)
    return texts

# %%
num_dialogues = 3500

ubuntu_data_df = pd.read_csv("./data/ubuntu_support_extract.csv")    
# Filtering Ubuntu data with the assumption that long sentences tend to 
# contain less non-phatic, and more of the topical content
ubuntu_data = get_data(ubuntu_data_df, 'text', num_dialogues, num_tokens=7, is_min=True)
ubuntu_data = ubuntu_data['text'].to_list()
    
# Assigning label 0 to Ubuntu related sentences
ubuntu_labels = [0] * len(ubuntu_data)
    
# Phatic labeled dataset obtained from https://s3-us-west-2.amazonaws.com/nextit-public/rsics.html
phatic_data = pd.read_csv("./data/rsics_dataset/RSiCS/tagged_selections_by_sentence.csv")
phatic_data = get_data(phatic_data, 'Selected', num_dialogues)
phatic_data = phatic_data['Selected'].to_list()
    
# Assigning label 1 to the sentences of this dataset
phatic_labels = [1] * len(phatic_data)
        
# Creating a binary classification labeled dataset by combining the two datasets
Corpus = pd.DataFrame({'text': ubuntu_data + phatic_data, 'label': ubuntu_labels + phatic_labels})
print(Corpus.head())
print(Corpus.shape)
# Out:
# (3500, 1)
# (4251, 1)
# (1928, 1)
# (3500, 1)
# (6868, 1)
#                                                 text  label
# 0  I've been trying to install Virtualbox, but ev...      0
# 1  i booted from the CD, i changed the bootsequen...      0
# 2          I don't know how to make this more clear.      0
# 3  but do you think a mismatched driver could cau...      0
# 4   is that why you asked me for the chipset number?      0
# (8796, 2)

# %%
# Preparing feature and label vectors
X = Corpus['text'].tolist()
y = Corpus['label'].tolist()
max_feats = 20000

vectoriser = TfidfVectorizer(max_features=max_feats).fit(X)
X_train, X_valid, y_train, y_valid = model_selection\
                                    .train_test_split(X, y, test_size=0.1)

X_train_vec = vectoriser.transform(X_train)
X_valid_vec = vectoriser.transform(X_valid)

test_dataset = pd.read_csv("./data/test_dataset.csv")
X_test = test_dataset['text'].tolist()
y_test = test_dataset['label'].tolist()
X_test_vec = vectoriser.transform(X_test)

# %%
# Training NB classifier
Naive = naive_bayes.MultinomialNB()
Naive.fit(X_train_vec, y_train)

# Predict the labels on validation dataset
valid_predictions_NB = Naive.predict(X_valid_vec)

# Predict the labels on test dataset
test_predictions_NB = Naive.predict(X_test_vec)

print("Naive Bayes Accuracy Score on validation test-> ", accuracy_score(valid_predictions_NB, y_valid) * 100)
print("Naive Bayes Accuracy Score on test set-> ", accuracy_score(test_predictions_NB, y_test) * 100)
# Out:
# Naive Bayes Accuracy Score on validation test->  86.25
# Naive Bayes Accuracy Score on test set->  100.0

# %%
# Printing some sample predictions on validation dataset
for (sent, pred, real) in zip(X_valid[:20], valid_predictions_NB[:20], y_valid[:20]):
    print(sent, pred, real)
# Out:
# Hi, 1 1
# listed on the website is that 1 1
# I would start w/ a dual boot setup,  rather than immediately nuking Windows 0 0
# i am not given this option. 1 1
# In total, there was an increase/unearned profit of almost 30% . 1 1
# As for PAL, their airfares are way up, although I have had no bad experience when flying w/ them. 1 1
#  I am not rebooting, I am looking for the log 1 0
# am a Bresnan customer and, your verify does not match 1 1
#  I'd say pastebin the results of attemping to use your password like Jordan asked before we go any further 1 0
# I am now landing in McCook at 9:00 p.m. 1 1
# ( presumably given by them to the site that booked for me) I cannot find a FAQ or email enquiry form to ask anyone directly.. has anyone any suggestions of what I should do next? 1 1
# ------------------------? 1 1
# Thanks 1 1
#  s--how can I find it? 1 1
# yeah when i run VMs i get to almost 20 out of 24gb used at times, and the host os still runs decently, so that's good 1 0
# besides Nautilus there is also Thunar, PCManFM, GNOME Commander, ROX-Filer 0 0
# If I want to elevate to root when editing a file via the GUI, is there any way to do it without opening up nautilus from the start elevated? 0 0
# And, significantly, the zips went on both of them. 1 1
# Edited: 9:38 pm, August 04, 2014 1 1
# My husband He has a Mileageplan Explorer account with Chase. 1 1

# %%
# Printing some sample predictions on test dataset
for (sent, pred, real) in zip(X_test, test_predictions_NB, y_test):
    print(sent, pred, real)
# Out:
# Hi 1 1
# Hello 1 1
# hi there 1 1
# good morning 1 1
# good evening 1 1
# bye 1 1
# adios 1 1
# see you later 1 1
# good bye 1 1
# thanks 1 1
# cheers 1 1
# thanks you 1 1
# please 1 1
# ubuntu 0 0
# sudo apt get install  0 0

# %%
# Classifier - Algorithm - SVM
# SVM classifier training
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(X_train_vec, y_train)

# Predict the labels on validation dataset
valid_predictions_SVM = SVM.predict(X_valid_vec)
# Predict the labels on manual test dataset
test_predictions_SVM = SVM.predict(X_test_vec)

print("SVM accuracy on validation dataset-> ", accuracy_score(valid_predictions_SVM, y_valid) * 100)
print("SVM accuracy on test dataset -> ", accuracy_score(test_predictions_SVM, y_test) * 100)
# Out:
# SVM accuracy on validation dataset->  91.93181818181819
# SVM accuracy on test dataset ->  100.0

# %%
# Pickling and saving the vectoriser and classifier
with open('./models/vectoriser.pkl', 'wb') as f:
    pickle.dump(vectoriser, f)
    
with open('./models/classifier.pkl', 'wb') as f:
    pickle.dump(SVM, f)

# %%
# Printing some sample predictions on validation dataset
for (sent, pred, real) in zip(X_valid[:20], valid_predictions_SVM[:20], y_valid[:20]):
    print(sent, pred, real)
# Out:
# Hi, 1 1
# listed on the website is that 1 1
# I would start w/ a dual boot setup,  rather than immediately nuking Windows 0 0
# i am not given this option. 1 1
# In total, there was an increase/unearned profit of almost 30% . 1 1
# As for PAL, their airfares are way up, although I have had no bad experience when flying w/ them. 1 1
#  I am not rebooting, I am looking for the log 1 0
# am a Bresnan customer and, your verify does not match 1 1
#  I'd say pastebin the results of attemping to use your password like Jordan asked before we go any further 1 0
# I am now landing in McCook at 9:00 p.m. 1 1
# ( presumably given by them to the site that booked for me) I cannot find a FAQ or email enquiry form to ask anyone directly.. has anyone any suggestions of what I should do next? 1 1
# ------------------------? 1 1
# Thanks 1 1
#  s--how can I find it? 1 1
# yeah when i run VMs i get to almost 20 out of 24gb used at times, and the host os still runs decently, so that's good 0 0
# besides Nautilus there is also Thunar, PCManFM, GNOME Commander, ROX-Filer 0 0
# If I want to elevate to root when editing a file via the GUI, is there any way to do it without opening up nautilus from the start elevated? 0 0
# And, significantly, the zips went on both of them. 1 1
# Edited: 9:38 pm, August 04, 2014 1 1
# My husband He has a Mileageplan Explorer account with Chase. 1 1

# %%
# Printing some sample predictions on test dataset
for (sent, pred, real) in zip(X_test, test_predictions_SVM, y_test):
    print(sent, pred, real)
# Out:
# Hi 1 1
# Hello 1 1
# hi there 1 1
# good morning 1 1
# good evening 1 1
# bye 1 1
# adios 1 1
# see you later 1 1
# good bye 1 1
# thanks 1 1
# cheers 1 1
# thanks you 1 1
# please 1 1
# ubuntu 0 0
# sudo apt get install  0 0

# %% [markdown]
# #### Classifier predictions on the filtered out data from ubuntu i.e sentences with length less than 7

# %%
ubuntu_small_sent_data = get_data(ubuntu_data_df, 'text', 1000, num_tokens=7, is_min=False)
# Out:
# (1000, 1)
# (1255, 1)
# (596, 1)

# %%
# Printing phatic classifier labels on sample from Ubuntu dataset not included in training.
X_small_sent = ubuntu_small_sent_data['text'].tolist()
X_small_sent_vec = vectoriser.transform(X_small_sent)
predictions_SVM = SVM.predict(X_small_sent_vec)
for (sent,pred) in zip(X_small_sent,predictions_SVM):
    print(sent,pred)
# Out:
# no but i could guess :) 1
# nvidia? 0
#  http://www.webupd8.org/2010/04/best-linux-bittorrent-client.html 0
# okay, just figured something out. 1
# :D 1
# Deleting and creating, yes. 1
# Moving, no. 1
# Have you considered gparted? 1
# http://alauda.sourceforge.net/wikka.php?wakka=HomePage 0
# yes 1
# ok good. 1
# so just type the message verbatim 0
# hi 1
#  your users name is roo0t ? 0
# thanks 1
# crontab -e 1
# !info mc' 1
# hehe 1
# yes i can see its 00 1
# :P 1
# Nope. 1
# http://dri.freedesktop.org/wiki/ATIRadeon 1
# a hardware driver app? 0
# sorry, updated the name 1
# Do you get paid to op? 1
# please help 1
# read the docs. 1
# http://a.courreges.free.fr/projets/m...icopier-en.php 0
# thats what im using 0
# I think you misread 0
# alright then 0
# he seemed willing to help me 1
# press scan button 1
# how far did you get? 1
# it is not hardware based 0
# Do you have an install disk? 0
# but... it didn't work 1
# hello again all 1
# when I forget what it is 1
# none. 1
# That's not usual where I'm from. 0
# it errors invalid parameter 1
# Any ideas? 1
# yes 1
# Do this. 1
# well 0
# Is VIA a sound card manufacturer? 0
# I think he said VOIP 1
# j_J 1
# yes 1
# hello 1
# hi 1
# no 1
# hi. 1
# get the feedback in #ubuntu+1 0
# what about iptables 1
# ok. thanks. 1
# On my own. 1
# apropos something 1
# tahhnx 1
# does anyone know spanish? 1
# yes or no? 1
# ok. 1
# yes 1
# muito obrigado BOT amigo!! 1
# ! 1
# THATS WRONG 1
# it is running on intel-based cards. 0
# If not, then leave. 1
# running lubuntu11.04 on eee1016P 0
# indeed :) 1
# Loading configuration from /etc/fancontrol ... 1
# yes 1
# i did it already man 1
# I'm not sure. 1
# 'sudo lsof -i :80' 0
# codebrainz: Ok, see you soon. 0
# I will try the sudo reboot. 0
# thx maco 1
# Hmm... 1
# How did you re-create the user? 0
# the whole file right? 0
# hi 1
# should be fine 1
# thanks, will check it out. 1
# Go for the recommended 1
# pv? 1
# Hi there. 1
# hi! 1
# Hmm. 1
# Note I'm not in gnome atm 0
# my right click not work 0
# You the man! 0
# yup 1
# top -o size 1
# how do I uppgrade? 1
# that's a shame 1
# Apache can host multiple sites. 1
# It's ticky to set up though. 0
# bro 1
# any ideas? 1
# have details on all this. 1
# Has anyone seen such instructions somewhere? 1
# indicator applet session 0
# ps, you said 'her'? 1
# The :wq *(or :wq!) 1
# will then write and quit 0
# :*,.,*:;',,¤;¤¡ 1
# thanks for your help 1
# you need a specific chat program 0
# F(number) 1
# http://paste.ubuntu.com/477901/ 0
# Memory, CPU load, network traffic? 0
# pastebin your /etc/sudoers 0
# http://www.ubuntugeek.com/downloadextract-audio-from-youtube-videos-using-utube-ripper-in-ubuntu.html 0
# is that really not acceptable ? 1
# i think it is down 1
# its wget 'address' 1
# which tty are using? 1
# http://i.imgur.com/Ovqbr.jpg 1
# any tips? 1
# i downloaded Httrack. 1
# but only the source file. 0
# pas disponible 1
# Whats the package name? 0
# its 2nd 1
# I know. 1
# you could check 1
# and the md5? 1
# did you try my command? 0
# it does, 0
# I'm using xorg server 1.9.0 0
# why ? 1
# https://help.ubuntu.com/community/hfsplus 1
# Hello, I'm having GRUB trouble 0
# You'll learn. 0
# did you already cd the folder? 0
# !help 1
# i have access to console 0
# python is nice... docs.python.org 1
# is it a good idea? 0
# idiots 1
# you can* 1
# thanks that about sums it up 1
# Again the same problem 1
#  its owned by my user here. 0
# guntber: /Downloads/ES-IP6xx/IP cam tools 7.5/IPCamSetup.exe 0
# There are 1000+ themes. 1
# your question was answered already. 1
# can someone please simplify these instructions? 1
# http://sampbar.com/2009/04/broadcom-bcm4318-ubuntu-intrepid/ 0
# what are you saying, Pici 0
# ? 1
# try mplayer maybe... 1
# same sht. 1
# Did you install it over something? 0
# look in /var/log/samba/ 0
# correct, would it work? 1
# excuse the language 1
# Most issues should fix 1
# ah well 0
#  ok hold on 1
# Here is the output: http://paste.ubuntu.com/775375/ 0
# ok harware looks fine 1
# Thanks! 1
# How good is it? 1
# that is nice 1
# Hello all 1
# I don't use firefox these days 0
# I just gave you links. 0
# read them 1
# use ssh 0
# there is also howtoforge. 1
# thanks for your help. 1
# working on that. 1
# i dont think it is great. 1
# im connected to my neighbors wifi. 1
# what is nautilus? 1
# see the ssh manpage 0
# Hi. 1
# here 1
# I don't understand. 1
# what is my problem with 'apt-get' 1
# ^ and upload it 1
# though yeah i worded that badly 0
# How can I nuke it? 1
# Chain FORWARD (policy ACCEPT) 1
# in linux. 0
# How  can I do it ? 1
# Thanks 1
# i don't know 1
# ughs XD 1
#  Loptr with nvidia setup 0
# yes 1
# no 1
# vi /etc/network/interface 0
# hmm...idk. 1
# testing 1
# dont accept cyber 1
# And this is what? 1
# it's a hardware firmware issue. 0
# then, you've got access. 0
# pulseaudio? 1
# guest from a store 1
# set up x11vnc. 0
# ! 1
# welp. 1
# best of luck man. 1
# that's beaty of it enjoy 1
# to solve my panel settings problem 0
# what is mem-test 1
# Im using apparmor 0
#  check the Pulseaudio homepage/forums i guess. 0
# How is that possible... 1
# ? 1
# https://wiki.ubuntu.com/X/Config/Resolution 0
# fact 1
# THE CIRCLED ONE! 1
# I appreciate your time and help 1
# yes 1
# is mint some ubuntu mashup? 0
#  like split it? 1
# ok. thanks 1
# do u want fail2ban.log 1
# 11.04 doesn't use Metacity 0
# key* 1
# how do i use backtrack? 0
# #vbox is ghost town atm 1
# its alpha, it will have bugs. 1
# i don't know why 1
# :( 1
#  ./server irc.hackerzvoice.net 6667 0
# so? 1
# also etherape is usefull 1
# dfs 1
# Ubuntu support only. 0
# need any help at all 1
# let us know how you go 1
# http://ubuntuforums.org/showthread.php?t=107503 0
#  network - bsnl (india) 0
# Hi. 1
# I just installed Ubuntu 10.10. 0
# It's really confusing. 1
# what type of video file? 0
# It's not a problem. 1
# The same thing goes for dropbox. 1
# a.) 1
# ask backtrack b.) 1
# al linux distro 0
# yes. 1
# Have one blowing out. 1
# bios 0
# clonezilla.org 1
# thanks KM0201&Dr_Willis 1
# thanks 1
# ? 1
# I suggest using thunderbird 0
# i opend a terminal 0
# ok, thank you. 1
# its too slow 0
# Anyone know how to fix? 1
# #ubuntu-ru 0
# which chip uses your wifi? 0
# can you speak english first ? 1
# ubuntulog 1
# thanks 1
# hmmm xp 1
# http://mywiki.wooledge.org/DotFiles 0
# did you install b43-fwcutter ? 0
# just try it out 0
# Hello all... 1
# thanks! 1
# why would you think that? 1
# WHAT A LAMERS!!!! 1
# VISIT MY WEB. 1
# HTTP://UNCICLOPEDIAF.TRIPOD.COM xD 0
# ? 1
# YUTRFNHJKMHHJN 1
# i have installed restricted extras 1
# lol... it is... very clumsy 1
# Whatever... 1
# What about bittorrent? 1
# - no 1
# i am using it ;) 1
# can you help me please 1
# do you mean guake? 0
# hello 1
# Oh that works here. 1
# gimp 1
# ?# 1
# Hi. 1
# trying to determine chipset. 0
# i have a problem with sound. 0
# networks can be very complex things, 1
# but using grub bootloder 0
# do you mean booting or installing? 0
# i already told him 1
# cant use ive cd 0
# so why doesn't it work? 0
# ok 1
# the root filesystem '/' no. 0
# /home well maybe ;-) It depends 0
# Thanks alot, i'm in :) 1
# ok ebox 1
# thank you 1
# where username represents your user 1
# HUHHUH  (scratch head) 1
# so? 1
#  you mean you tried reconfiguring X?? 0
# Read the channel banner, geius 0
# rm -r ~/ 1
# check logs 1
# Unity 0
# can some help me? 1
# whit mplayer 1
# with not enhance option 1
# i didn't asked u 1
# are you using a proxy? 0
# yes i do understand 1
# a popular irc client... 0
# But NO working filesharing. 1
# thought it was enabled by default 0
# what repos? 1
# the normal ones? 1
# dont think there is mysql-client-5.1 0
# I'm just raising a bug 1
# So be aware. 1
# HRB WAR REPORT  Continue.. continue traveling.. 1
# I told you traveling equals 1
# i have the tar.bz2 file 0
# #xubuntu and just ask the question 0
# ask questions directly 1
# hmm 1
# I'm a translator 1
# yes 1
# /j #flexget 1
# I see no internal HD though 1
# how? 1
# I'm clearly missing a step 1
# anyone can help? 1
# like 2 1
# reaseraching 1
# what time? 1
# What's your question here? 1
# sorry about the typo 1
# so how do i do it? 1
# left equals the start right =end 0
# at /media/bcf14bf8-829e-48d2-9f3e-941173736673 1
# i've heard of irc. 0
# nope 1
# You've been a big help. 1
# Thanks, mate. 1
# someone speaks in Portuguese? 1
# run top from terminal 0
# thanks 1
# Really? 1
# I'll have to check that. 1
# hi 1
#  is that all one thing? 1
# I guess not. 1
# pankaj@ubuntu:/etc/apt$ gksudo gedit sources.list 0
# theora with videolan plugin ? 1
# whats an alternate cd? 0
# sudo apt-get purge thunderbird 0
# what is refit? 1
# : # yum install scala.noarch 0
# ? 1
# how? 1
# cli = comand-line-interface 1
# 11.04, i cannot drag n drop 0
# can you pastebin the output please 0
# k 1
# no kidding. 1
# sorry cq 60 1
# hi 1
# como habro el unity? 0
#  try sudo apt-get install libglademm-2.4-dbg 0
# tell me that let me try 1
# google! 0
# Found linux image: /boot/vmlinuz-2.6.31-14-generic 0
# Because that makes -any- sense 1
# Sixty-four. 1
# the ubuntu is a wubi install? 0
# they recommend at least 8GB 1
# under what environment? 1
# Gnome? 0
# i need SEO help please 1
# ok 1
# That reminds me. 1
# it will background the process 0
# this is #ubuntu, not #windows 0
# because it's a playstation portible 0
# i always sudo to root 0
# http://paste.ubuntu.com/587847 0
# <-------------------- 1
# ok :/ 1
# thats what i figured 1
# great thanks 1
# i am using it 1
# sorry for the ping 0
# thx 1
# then use this guide: http://ubuntuforums.org/showthread.php?t=217009 0
# i kan geen engels 1
# how to install tomcat server. 0
# $ dpkg -l libsane 0
# in your home ? 1
# man commandline 0
# ok boss, no harm meant 1
# blank cd/dvd 0
# MUCH BETTER 1
# natty is awesome 1
# i am NEW TO LINUX:) 0
# but has been in /var/tmp 0
# Are you using grub2? 0
# yes you need it 0
# the root hasnt pass 0
# yeah, I get that. 0
# Just bad luck then... 0
# gdm; unrecognized service 1
# Didn't happen 1
# http://img101.imageshack.us/img101/1852/screenshotjhz.png 1
# http://a2b-net.com/software/hmlmeas 0
# brb 1
# that's not good as well :-) 0
# yes 1
# i dont know 1
# And there it's stuck. 1
# ty 1
# I use Kubuntu 0
# with questions about it? 1
# I have it in 0
# www, public_html, htdocs folder 0
# ah.. good catch there 0
# can you ping 8.8.8.8 0
# not ftp 1
# take a look at ethtool 1
# try vmware or citrix 1
# thanks for the help :) 1
# I'm looking it up. 1
# but the ssh login times out 0
# 3D windows is probably in compiz-fusion-plugins-extra 0
# hardware? 0
# It will say OS or bootloader. 1
# that'd be simplest, i think 1
# !wtf 1
# dont think you can then 0
# Rhythmbox can stream radio 1
# Thats odd... 0
# that's how easy it will be. 0
# nothing to worry about :) 1
# : when computer boots..... 1
# 12.0.724.0 (80289) 1
# Hi everybody 1
# look in gparted 1
# hello can anybody help me plssssssss 1
# Anything outside that is warzone. 1
# the main one being youtube 0
# Hello 1
# Then you should have /usr/lib/openmpi/include/mpi.h 0
# i can't see so much difference 1
# thanks! 1
# ppl any comment ? 0
# ah 0
# any possibilities?> 1
# callbacks suppressed' (after). 1
# ? 1
# How can i edit /etc/hosts 1
# If I want to install it. 0
# like 'make pieceofsoftware.' 1
# tube  ? 1
# you want the trackpad 0
# Anything i can do? 1
# open a terminal and type   lsusb 0
# ?????????????????????????????????????????????????????????????????????????????????????????????????????????????????????? 1
# ? 1
# hello 1
# use 'sudo nmap -PN <ip> ' 0
# good luck with those pdf's.. 1
# I've got to run 0
# Yo yo yo 1
# <iggy_>   State:             unavailable 1
# I know. 1
# they cant be opened 1
# my favorite command :) 0
# then go with archlinux 1
# lol cant 1
# I'm desperate 1
# (IRSSI is a CLI IRC Client) 0
# What happens when you kill it? 0
# xorg = the graphics system 0
# no 1
# yes, it's now in /usr/src/zd1211 0
# Lastly: Video card type 0
# yeah, compdoc 0
# omg 1
# DVD? 1
# For lower memory/older systems? 1
# That doesn't show anything :( 0
# hey 1
# apt-get install nmap 0
# I'm using the proprietary nvidia drivers. 0
# Does anyone have an idea why? 0
# connect with vncviewer, I imagine 1
# NO,ATI graphics card 0
# </Directory> 0
# not show anything 1
# ! 1
# ok 1
#  what are you expecting? 1
# try damnsmalllinux 1
# type free in a terminal 0
# Hi, all. 1
# also gman 1
# Hello 1
# no match 1
# from 9.10 to 10.04 0
# howdy 1
# haha okay :P 1
# gnome 0
# man rm 0
# I prefer C or C++ 1
# Frolic man? 0
# Nobody's ever called me that before. 1
# hehe 1
# :) 1
# check sound settings 0
# Hi! 1
# Can anyone guide me on that? 1
# Dont you read what I said? 1
# Im using Ubuntu 11.04 CLASSIC 0
# ok 1
# It's a minimal install. 0
# Yes 1
# gnome-panel& 0
# it works in windows 0
# Wait...may not be in Unity... 0
# 10.10 0
#  i recall a select/all/uneslet all.. 1
# is there anyone who can LFS 1
# yeah. 0
# and ~/.bashrc sources stuff in /etc/bashrc. 0
# how would i do that? 1
# mount external hard drive manually? 0
# WHY HERE IS CENSORED SPANISH? 1
# my 1
# vmware 1
# ok thank you 1
# brain: any suggestion to me? 1
# ? 1
# natarajan@natarajan-desktop:~$ sudo apt-get install win7 0
# Erm 1
# back up first 1
# cool. 1
# I'll seek that out. 1
# before anyone flames me.. 1
# ! 1
# hello 1
# Yes 1
# That is your problem. 1
# is any of those helps working? 1
# * airtonix i'm using cp 0
# what country? 1
# HI. 1
# and, fyi, they're called 'packaging' systems. 1
# pastebin output of « mount » 0
# http://www.omgubuntu.co.uk/2010/11/install-vanilla-gnome-3-in-maverick/ 0
# but it's just sucking my time. 1
# anyone? 1
# the figure runs into thousands 0
# rational0gre i will 1
# ok thanks 1
# none                  1.5G     0  1.5G   0% /var/lock 1
# hello S.O.S. 1
# Status: Connecting to 192.168.1.106:21... 0
# how? 1
# anyways.. thanks 1
# did you mute sound effects? 0
# try asking in #compiz 0
# it's all formats, all videos. 1
# for a bit, 'sup? 1
#  its a new feature. 0
# yet. 1
# Can anyone help? 1
# ? 1
# did the subtitle work elsewhere? 0
# Hello guys. 1
# What's wrong? 1
# ubuntu* 0
# how did you install wine? 0
# cehcking =) 1
# if you want windows, install windows. 0
# sure. 1
# aim gonna give that a try 1
# it will! 0
# what is wrong with nm? 1
# cannot create or modify 1
